# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Load dataset
df = pd.read_csv(r"C:\\Users\\Adhit.LAPTOP-4TQ0Q0P2\\OneDrive\\Desktop\\Internship\\IMDB Dataset.csv")

# Convert labels
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})

# Split
X_train, X_test, y_train, y_test = train_test_split(
    df['review'], df['sentiment'], test_size=0.2, random_state=42
)

# %%
tfidf = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

lr = LogisticRegression(max_iter=200)
lr.fit(X_train_tfidf, y_train)
y_pred_lr = lr.predict(X_test_tfidf)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))

cm = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Logistic Regression Confusion Matrix")
plt.show()
# Out:
# Logistic Regression Accuracy: 0.8951
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      4961
#            1       0.89      0.91      0.90      5039
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.89      0.90     10000
# weighted avg       0.90      0.90      0.90     10000

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(X_train_tfidf, y_train)
y_pred_nb = nb.predict(X_test_tfidf)

print("Naive Bayes Accuracy:", accuracy_score(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb))

cm = confusion_matrix(y_test, y_pred_nb)
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens')
plt.title("Naive Bayes Confusion Matrix")
plt.show()
# Out:
# Naive Bayes Accuracy: 0.8508
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      4961
#            1       0.85      0.85      0.85      5039
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000

# %%
print("\n--- Model Performance Summary ---")
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
print("Naive Bayes Accuracy:", accuracy_score(y_test, y_pred_nb))
# Out:
# --- Model Performance Summary ---
# Logistic Regression Accuracy: 0.8951
# Naive Bayes Accuracy: 0.8508

# %%
In this project, we performed sentiment analysis on the IMDB movie reviews dataset.
The text data was preprocessed using TF-IDF vectorization, and two machine learning models were applied: Logistic Regression and Naive Bayes.
Both models were trained and tested on the dataset, and their performance was evaluated using accuracy, classification reports, and confusion matrices.
From the results, we observed that Logistic Regression achieved higher accuracy compared to Naive Bayes, making it more effective for this dataset.
The confusion matrices further highlighted the classification performance of both models.
This study demonstrates how sentiment analysis can be implemented using traditional machine learning approaches for text classification. 
With more computational resources, deep learning models such as LSTM could also be explored to capture deeper contextual information from text.
